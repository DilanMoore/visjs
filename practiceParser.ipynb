# %%
import json

# %%
with open('sessions.json', 'r') as f:
  input_json = json.load(f)

# %%
# Serializing json
json_object = json.dumps(input_json)
 
# Writing to sample.json
with open("session.js", "w") as outfile:
    outfile.write(json_object)

# %%
json_object
# Out:
# '[{"id": 0, "datetime": 1704888628606658800, "player": "drew.lennon@uptimelabs.io", "scenario": "online-boutique", "level": 15, "session_id": 1446, "message": "can we verify if the product issue is fixed Bob Shay", "date": "2024-01-10"}, {"id": 1, "datetime": 1704888645674989000, "player": "Bob", "scenario": "online-boutique", "level": 15, "session_id": 1446, "message": "Looks like the products are visible now, but still seeing the payment issues", "date": "2024-01-10"}, {"id": 2, "datetime": 1704888651974179000, "player": "Tanya", "scenario": "online-boutique", "level": 15, "session_id": 1446, "message": "hey <https://docs.ob.uptimelabs.io/docs/runbooks/services/checkout/#enabling-btc-payment>", "date": "2024-01-10"}, {"id": 3, "datetime": 1704888668532829000, "player": "Tanya", "scenario": "online-boutique", "level": 15, "session_id": 1446, "message": "this says we need to disable the feature flag", "date": "2024-01-10"}, {"id": 4, "datetime": 1704888687658209000, "player": "Tanya"
# ...

# %%
input_json
# Out:
# [{'id': 0,
#   'datetime': 1704888628606658800,
#   'player': 'drew.lennon@uptimelabs.io',
#   'scenario': 'online-boutique',
#   'level': 15,
#   'session_id': 1446,
#   'message': 'can we verify if the product issue is fixed Bob Shay',
#   'date': '2024-01-10'},
#  {'id': 1,
#   'datetime': 1704888645674989000,
#   'player': 'Bob',
#   'scenario': 'online-boutique',
#   'level': 15,
#   'session_id': 1446,
#   'message': 'Looks like the products are visible now, but still seeing the payment issues',
#   'date': '2024-01-10'},
#  {'id': 2,
#   'datetime': 1704888651974179000,
#   'player': 'Tanya',
#   'scenario': 'online-boutique',
#   'level': 15,
#   'session_id': 1446,
#   'message': 'hey <https://docs.ob.uptimelabs.io/docs/runbooks/services/checkout/#enabling-btc-payment>',
#   'date': '2024-01-10'},
#  {'id': 3,
#   'datetime': 1704888668532829000,
#   'player': 'Tanya',
#   'scenario': 'online-boutique',
#   'level': 15,
#   'session_id': 1446,
# ...

# %%
output_json = []

for entry in input_json:
    session_id = entry['session_id']
    message_entry = {
        
        "message": entry['message'],
        "player": entry['player'],
        "datetime": entry['date']  # Assuming 'date' is in the desired format
    }

    output_json.append(message_entry)

# %% [markdown]
# {"id":5609,
# "datetime":"2023-09-07 07:47:25.867",
# "player":"UptimeLabs",
# "scenario":"online-boutique",
# "level":1.0,
# "session_id":1000.0,
# "message":"UptimeLabs has joined the channel",
# "date":"2023-09-07"}

# %%
output_json
# Out:
# [{'message': 'can we verify if the product issue is fixed Bob Shay',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-10'},
#  {'message': 'Looks like the products are visible now, but still seeing the payment issues',
#   'player': 'Bob',
#   'datetime': '2024-01-10'},
#  {'message': 'hey <https://docs.ob.uptimelabs.io/docs/runbooks/services/checkout/#enabling-btc-payment>',
#   'player': 'Tanya',
#   'datetime': '2024-01-10'},
#  {'message': 'this says we need to disable the feature flag',
#   'player': 'Tanya',
#   'datetime': '2024-01-10'},
#  {'message': 'Drew Lennon, can you escalate to Bob?',
#   'player': 'Tanya',
#   'datetime': '2024-01-10'},
#  {'message': 'yes can do Tanya, can you look into it Bob?',
#   'player': 'drew.lennon@uptimelabs.io',
#   'datetime': '2024-01-10'},
#  {'message': 'BTC is not an option of the fronend so how is it being used as an option',
#   'player': 'conail@uptimelabs.io',
#   'datetime': '2024-01-10'},
# ...

# %%
# Serializing json
json_object = json.dumps(output_json)
 
# Writing to sample.json
with open("session.js", "w") as outfile:
    outfile.write(json_object)

# %% [markdown]
# [
#     {
#         "session_id": 1000,
#         "messages": [
#             {
#                 "message": "UptimeLabs has joined the channel",
#                 "player": "UptimeLabs",
#                 "datetime": "2023-09-07T06:47:25.867Z"
#             },
#             {
#                 "message": "UptimeLabs has joined the channel",
#                 "player": "UptimeLabs",
#                 "datetime": "2023-09-07T06:47:25.925Z"
#             }...
# ...
# ]
